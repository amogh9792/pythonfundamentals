# %%
#pip install mysql-connector-python

# %%
pip install mysql-connector

# %%
import mysql.connector as conn
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
myconn = conn.connect(host='localhost', user='root',passwd='12345')

# %%
import mysql.connector

# Get the version of mysql-connector-python
version = mysql.connector.__version__

print(f"mysql-connector-python version: {version}")
# Out:
# mysql-connector-python version: 8.0.32

# %%
cursor = myconn.cursor()

# %%
result = cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
query = 'use world'

cursor.execute(query)

print(cursor.fetchall())
# Out:
# []

# %%
SELECT <column name(s)>
FROM <table>
WHERE <condition>

# %%
query = """
SELECT *
FROM city
"""

data = pd.read_sql_query(query, myconn)

data
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
data.to_csv("city.csv",index = False)

# %%
query = """
SELECT *
FROM country
"""

data = pd.read_sql_query(query, myconn)

data
data.head(2)
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# 1  Afganistan/Afqanestan                               Islamic Emirate
#
#      HeadOfState  Capital Code2
# 0        Beatrix    129.0    AW
# 1  Mohammad Omar      1.0    AF

# %%
query = """
SELECT *
FROM countrylanguage
"""

data = pd.read_sql_query(query, myconn)
print(data.shape)
data
# Out:
# (984, 4)
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]

# %%
data[data['CountryCode'] == 'IND']
# Out:
#     CountryCode   Language IsOfficial  Percentage
# 394         IND      Asami          F         1.5
# 395         IND    Bengali          F         8.2
# 396         IND   Gujarati          F         4.8
# 397         IND      Hindi          T        39.9
# 398         IND    Kannada          F         3.9
# 399         IND  Malajalam          F         3.6
# 400         IND    Marathi          F         7.4
# 401         IND      Orija          F         3.3
# 402         IND    Punjabi          F         2.8
# 403         IND      Tamil          F         6.3
# 404         IND     Telugu          F         7.8
# 405         IND       Urdu          F         5.1

# %%
data[data['Language'] == 'English'].head(3)
# Out:
#    CountryCode Language IsOfficial  Percentage
# 1          ABW  English          F         9.5
# 18         AIA  English          T         0.0
# 27         ANT  English          F         7.8

# %% [markdown]
# Read selected Columns

# %%
query = """
SELECT CountryCode, Language
FROM countrylanguage
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
#     CountryCode    Language
# 0           ABW       Dutch
# 1           ABW     English
# 2           ABW  Papiamento
# 3           ABW     Spanish
# 4           AFG     Balochi
# ..          ...         ...
# 979         ZMB      Tongan
# 980         ZWE     English
# 981         ZWE     Ndebele
# 982         ZWE      Nyanja
# 983         ZWE       Shona
#
# [984 rows x 2 columns]

# %%
#data['Language'].uniqueque()

# %% [markdown]
# Extract unique values of table column

# %%
query = """
SELECT DISTINCT CountryCode 
FROM CountryLanguage
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
#     CountryCode
# 0           ABW
# 1           AFG
# 2           AGO
# 3           AIA
# 4           ALB
# ..          ...
# 228         YEM
# 229         YUG
# 230         ZAF
# 231         ZMB
# 232         ZWE
#
# [233 rows x 1 columns]

# %%
data['CountryCode'].value_counts()
# Out:
# CountryCode
# ABW    1
# PAN    1
# NER    1
# NFK    1
# NGA    1
#       ..
# GRC    1
# GRD    1
# GRL    1
# GTM    1
# ZWE    1
# Name: count, Length: 233, dtype: int64

# %%
query = """
SELECT *
FROM CountryLanguage
WHERE Isofficial = 'T'
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
#     CountryCode   Language IsOfficial  Percentage
# 0           ABW      Dutch          T         5.3
# 1           AFG       Dari          T        32.1
# 2           AFG     Pashto          T        52.4
# 3           AIA    English          T         0.0
# 4           ALB  Albaniana          T        97.9
# ..          ...        ...        ...         ...
# 233         ZAF  Afrikaans          T        14.3
# 234         ZAF    English          T         8.5
# 235         ZAF      Xhosa          T        17.7
# 236         ZAF       Zulu          T        22.7
# 237         ZWE    English          T         2.2
#
# [238 rows x 4 columns]

# %%
data['IsOfficial'].unique()
# Out:
# array(['T'], dtype=object)

# %% [markdown]
# Extract records based on mathematical condition

# %%
query = """
SELECT *
FROM CountryLanguage
WHERE Percentage > 75
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
#     CountryCode        Language IsOfficial  Percentage
# 0           ABW      Papiamento          F        76.7
# 1           ALB       Albaniana          T        97.9
# 2           ANT      Papiamento          T        86.2
# 3           ARG         Spanish          T        96.8
# 4           ARM        Armenian          T        93.4
# ..          ...             ...        ...         ...
# 118         VEN         Spanish          T        96.9
# 119         VIR         English          T        81.7
# 120         VNM      Vietnamese          T        86.8
# 121         YEM          Arabic          T        99.6
# 122         YUG  Serbo-Croatian          T        75.2
#
# [123 rows x 4 columns]

# %% [markdown]
# Extract data based on two conditions

# %%
query = """
SELECT *
FROM CountryLanguage
WHERE Percentage > 75
AND IsOfficial = 'T'
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
#    CountryCode        Language IsOfficial  Percentage
# 0          ALB       Albaniana          T        97.9
# 1          ANT      Papiamento          T        86.2
# 2          ARG         Spanish          T        96.8
# 3          ARM        Armenian          T        93.4
# 4          ASM          Samoan          T        90.6
# ..         ...             ...        ...         ...
# 89         VEN         Spanish          T        96.9
# 90         VIR         English          T        81.7
# 91         VNM      Vietnamese          T        86.8
# 92         YEM          Arabic          T        99.6
# 93         YUG  Serbo-Croatian          T        75.2
#
# [94 rows x 4 columns]

# %%
query = """
SELECT *
FROM CountryLanguage
WHERE Percentage > 75
OR IsOfficial = 'T'
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW  Papiamento          F        76.7
# 2           AFG        Dari          T        32.1
# 3           AFG      Pashto          T        52.4
# 4           AIA     English          T         0.0
# ..          ...         ...        ...         ...
# 262         ZAF   Afrikaans          T        14.3
# 263         ZAF     English          T         8.5
# 264         ZAF       Xhosa          T        17.7
# 265         ZAF        Zulu          T        22.7
# 266         ZWE     English          T         2.2
#
# [267 rows x 4 columns]

# %% [markdown]
# Read Data from table 'city' where country in 'IND' and city is 'Delhi'

# %%
query = """
SELECT *
FROM city
WHERE CountryCode = 'IND'
AND Name = 'Delhi'
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
#      ID   Name CountryCode District  Population
# 0  1025  Delhi         IND    Delhi     7206704

# %%
my_city_list = ['Delhi', 'Mumbai', 'Chennai']

query = """
SELECT *
FROM city
WHERE CountryCode = 'IND'
AND Name IN {tuple(my_city_list)}
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:608, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     607         query = query.encode("utf-8")
# --> 608     self._cmysql.query(
#     609         query,
#     610         raw=raw,
#     611         buffered=buffered,
#     612         raw_as_string=raw_as_string,
#     613         query_attrs=self._query_attrs,
#     614     )
#     615 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '{tuple(my_city_list)}' at line 4
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2202, in SQLiteDatabase.execute(self, sql, params)
#    2201 try:
# -> 2202     cur.execute(sql, *args)
#    2203     return cur
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:330, in CMySQLCursor.execute(self, operation, params, multi)
#     329 try:
# --> 330     result = self._cnx.cmd_query(
#     331         stmt,
#     332         raw=self._raw,
#     333         buffered=self._buffered,
#     334         raw_as_string=self._raw_as_string,
#     335     )
#     336 except MySQLInterfaceError as err:
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:616, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     615 except MySQLInterfaceError as err:
# --> 616     raise get_mysql_exception(
#     617         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     618     ) from err
#     619 except AttributeError as err:
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '{tuple(my_city_list)}' at line 4
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[45], line 10
#       1 my_city_list = ['Delhi', 'Mumbai', 'Chennai']
#       3 query = """
#       4 SELECT *
#       5 FROM city
#       6 WHERE CountryCode = 'IND'
#       7 AND Name IN {tuple(my_city_list)}
#       8 """
# ---> 10 data = pd.read_sql_query(query, myconn)
#      11 data
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:469, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     466     dtype_backend = "numpy"  # type: ignore[assignment]
#     468 with pandasSQL_builder(con) as pandas_sql:
# --> 469     return pandas_sql.read_query(
#     470         sql,
#     471         index_col=index_col,
#     472         params=params,
#     473         coerce_float=coerce_float,
#     474         parse_dates=parse_dates,
#     475         chunksize=chunksize,
#     476         dtype=dtype,
#     477         dtype_backend=dtype_backend,
#     478     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2266, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2255 def read_query(
#    2256     self,
#    2257     sql,
#    (...)
#    2264     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2265 ) -> DataFrame | Iterator[DataFrame]:
# -> 2266     cursor = self.execute(sql, params)
#    2267     columns = [col_desc[0] for col_desc in cursor.description]
#    2269     if chunksize is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2214, in SQLiteDatabase.execute(self, sql, params)
#    2211     raise ex from inner_exc
#    2213 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2214 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT *
# FROM city
# WHERE CountryCode = 'IND'
# AND Name IN {tuple(my_city_list)}
# ': 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '{tuple(my_city_list)}' at line 4

# %% [markdown]
# Get result in sorted form

# %%
query = """
SELECT *
FROM city
ORDER BY Population ASC
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
#         ID                Name CountryCode      District  Population
# 0     2912           Adamstown         PCN             –          42
# 1     2317         West Island         CCK   West Island         167
# 2     3333             Fakaofo         TKL       Fakaofo         300
# 3     3538  Città del Vaticano         VAT             –         455
# 4     2316              Bantam         CCK   Home Island         503
# ...    ...                 ...         ...           ...         ...
# 4074   939             Jakarta         IDN  Jakarta Raya     9604900
# 4075  1890            Shanghai         CHN      Shanghai     9696300
# 4076   206           São Paulo         BRA     São Paulo     9968485
# 4077  2331               Seoul         KOR         Seoul     9981619
# 4078  1024     Mumbai (Bombay)         IND   Maharashtra    10500000
#
# [4079 rows x 5 columns]

# %% [markdown]
# Read data from table 'city' with name is ascending order and population in descending order.

# %%
query = """
SELECT *
FROM city
ORDER BY Name ASC, Population DESC
"""

data = pd.read_sql_query(query, myconn)
data
# Out:
#         ID                          Name CountryCode             District  \
# 0      698  [San Cristóbal de] la Laguna         ESP       Canary Islands
# 1       20              ´s-Hertogenbosch         NLD        Noord-Brabant
# 2      670          A Coruña (La Coruña)         ESP              Galicia
# 3     3097                        Aachen         DEU  Nordrhein-Westfalen
# 4     3318                       Aalborg         DNK          Nordjylland
# ...    ...                           ...         ...                  ...
# 4074  2025                         Zunyi         CHN              Guizhou
# 4075  3245                        Zürich         CHE               Zürich
# 4076  3145                       Zwickau         DEU                Saksi
# 4077    28                        Zwolle         NLD           Overijssel
# 4078  3446                       Zytomyr         UKR              Zytomyr
#
#       Population
# 0         127945
# 1         129170
# 2         243402
# 3         243825
# 4         161161
# ...          ...
# 4074      261862
# 4075      336800
# 4076      104146
# 4077      105819
# 4078      297000
#
# [4079 rows x 5 columns]
